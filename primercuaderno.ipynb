# %% [markdown]
# # MI PRIMER CUADERNO
# ## este va a ser mi primer cuaderno
# ### hecho por Tomás Ladiani [REFERENCIA](https://github.com/tomyladiani)
#
# se puede hacer:
# - bla bla bla
# - bla bla cursivas *bla bla*
# - bla bla bla negritas **bla bla**
#
# ![imagen](https://imagenes.elpais.com/resizer/v2/4GFYMYJE5ZDWXGOEOYWI7XSIAQ.webp?auth=939bbdc075663f2fb475da43632698c9eb82ad785bba2edc8c09a60e67f7fc6e&width=414)

# %%
print("Este es el bloque 1")
x = 10
# Out:
# Este es el bloque 1

# %%
print("segundo bloque: \n")
print("la variable es: ", x)
# Out:
# segundo bloque:
#
# la variable es:  10

# %%
print("tercer bloque: \n")
y = x + 10
print("la variable x + 10 es: ", y)
# Out:
# tercer bloque:
#
# la variable x + 10 es:  20

# %% [markdown]
# gracias Profe([REF](https://github.com/marianux)) y Elliot Hoffman de youtube([REF](https://www.youtube.com/watch?v=6Vr9ZUntCyE)).
